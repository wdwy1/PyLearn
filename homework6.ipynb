# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif']=['SimHei']   # 用黑体显示中文

line1=plt.bar(1,1,width=1.2,color='pink')
line2=plt.bar(1,1,bottom=1,width=1,color='red')
line3=plt.bar([0.6,0.8,1.0,1.2,1.4],[2,2,2,2,2],width=0.1,bottom=2,color='green')
plt.plot([0.6,0.6],[4.0,4.5])
plt.plot([0.8,0.8],[4.0,4.5])
plt.plot([1.0,1.0],[4.0,4.5])
plt.plot([1.2,1.2],[4.0,4.5])
plt.plot([1.4,1.4],[4.0,4.5])
plt.plot([0.55,0.65],[3.0,4.0],color='white')
plt.plot([0.55,0.65],[2.0,3.0],color='white')
plt.plot([0.75,0.85],[3.0,4.0],color='white')
plt.plot([0.75,0.85],[2.0,3.0],color='white')
plt.plot([0.95,1.05],[3.0,4.0],color='white')
plt.plot([0.95,1.05],[2.0,3.0],color='white')
plt.plot([1.15,1.25],[3.0,4.0],color='white')
plt.plot([1.15,1.25],[2.0,3.0],color='white')
plt.plot([1.35,1.45],[3.0,4.0],color='white')
plt.plot([1.35,1.45],[2.0,3.0],color='white')
plt.plot([0.4,1.6],[0.4,0.4],color='white',linewidth=5)
plt.plot([0.4,1.6],[0.2,0.2],color='white')
plt.plot([0.4,1.6],[0.7,0.7],color='white',linewidth=2)
plt.plot([0.5,1.5],[1.4,1.4],color='white',linewidth=5)
plt.plot([0.5,1.5],[1.2,1.2],color='white')
plt.plot([0.5,1.5],[1.7,1.7],color='white',linewidth=2)


np.random.seed(19680801)
N = 150
x = np.random.rand(N)*2
y = np.random.rand(N)*6
colors = np.random.rand(N)
plt.scatter(x,y,s=1,c=colors)
plt.title("生日快乐",fontsize=25)
plt.legend(([line1,line2,line3]),('第一层蛋糕','第二层蛋糕','蜡烛'))
plt.axis('off')
# Out:
# (-0.09117246455193173, 2.0790048955035076, 0.0, 6.269855822442934)
